# %%
import array
l1=[]
i=0
print("Enter Elements:")
while e!="stop":
    e=input("Element:")
    l1[i]=e
    i+=1

# %%
l1=[None]*5
for i in range(len(l1)):
    l1[i]=int(input("Enter Element:"))
for i in range(len(l1)):  
    print(f"Position {i} :{l1[i]}")
# Out:
# Position 0 :5
# Position 1 :676
# Position 2 :89
# Position 3 :6
# Position 4 :5

# %%
l1=[None]*5
for i in range(len(l1)):
    l1[i]=int(input("Enter Element:"))
for i in range(len(l1)):  
    #print(f"Position {i} :{id(l1[i])}, Address:{id(l1[i])}")
    #print(f"Position {i} :{id(l1[i])}, Address:{l1.buffer_info()[i]}")
    print(f"Position {i} :{id(l1[i])}, Address:{l1[i
                                                   +].buffer_info()}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 7
#       3     l1[i]=int(input("Enter Element:"))
#       4 for i in range(len(l1)):
#       5     #print(f"Position {i} :{id(l1[i])}, Address:{id(l1[i])}")
#       6     #print(f"Position {i} :{id(l1[i])}, Address:{l1.buffer_info()[i]}")
# ----> 7     print(f"Position {i} :{id(l1[i])}, Address:{l1[i].buffer_info()}")
#
# AttributeError: 'int' object has no attribute 'buffer_info'
